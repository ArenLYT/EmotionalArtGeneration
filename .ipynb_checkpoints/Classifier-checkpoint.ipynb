# %%
from fastai.data.all import *
from fastai.vision.all import *
import fastai
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ArtEmisv2.csv')
df
# Out:
#             emotion           art_style  \
# 0              fear  Art_Nouveau_Modern
# 1           sadness  Post_Impressionism
# 2              fear  Post_Impressionism
# 3              fear  Post_Impressionism
# 4       contentment  Post_Impressionism
# ...             ...                 ...
# 237993        anger       Expressionism
# 237994      sadness       Expressionism
# 237995         fear       Expressionism
# 237996      sadness       Expressionism
# 237997      disgust       Expressionism
#
#                                         painting
# 0           a.y.-jackson_algoma-in-november-1935
# 1                        a.y.-jackson_barns-1926
# 2                        a.y.-jackson_barns-1926
# 3                        a.y.-jackson_barns-1926
# 4          a.y.-jackson_early-spring-quebec-1923
# ...                                          ...
# 237993  zinaida-serebriakova_young-moroccan-1932
# 237994  zinaida-serebriakova_young-moroccan-1932
# 237995  zinaida-serebriakova_young-moroccan-1932
# 237996  zinaida-serebriakova_young-moroccan-1932
# 237997  zinaida-serebriakova_young-moroccan-1932
#
# [237998 rows x 3 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*1.0 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
def emtype(x):
    if x.emotion=='sadness':
        return "negative"
    elif x.emotion=='fear':
        return "negative"
    elif x.emotion=='disgust':
        return "negative"
    elif x.emotion=='anger':
        return "negative"
    elif x.emotion=='contentment':
        return "positive"
    elif x.emotion=='awe':
        return "positive"
    elif x.emotion=='amusement':
        return "positive"
    elif x.emotion=='excitement':
        return "positive"
    else:
        return "something else"

# %%
dfemo=df
dfemo['emotype']= dfemo.apply(emtype,axis=1)
dfemo
# Out:
#             emotion           art_style  \
# 0              fear  Art_Nouveau_Modern
# 1           sadness  Post_Impressionism
# 2              fear  Post_Impressionism
# 3              fear  Post_Impressionism
# 4       contentment  Post_Impressionism
# ...             ...                 ...
# 237993        anger       Expressionism
# 237994      sadness       Expressionism
# 237995         fear       Expressionism
# 237996      sadness       Expressionism
# 237997      disgust       Expressionism
#
#                                         painting   emotype
# 0           a.y.-jackson_algoma-in-november-1935  negative
# 1                        a.y.-jackson_barns-1926  negative
# 2                        a.y.-jackson_barns-1926  negative
# 3                        a.y.-jackson_barns-1926  negative
# 4          a.y.-jackson_early-spring-quebec-1923  positive
# ...                                          ...       ...
# 237993  zinaida-serebriakova_young-moroccan-1932  negative
# 237994  zinaida-serebriakova_young-moroccan-1932  negative
# 237995  zinaida-serebriakova_young-moroccan-1932  negative
# 237996  zinaida-serebriakova_young-moroccan-1932  negative
# 237997  zinaida-serebriakova_young-moroccan-1932  negative
#
# [237998 rows x 4 columns]

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()

dfemo

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotype"].agg(modo).reset_index()

dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 51514                 Ukiyo_e
# 51515                 Ukiyo_e
# 51516                 Ukiyo_e
# 51517                 Ukiyo_e
# 51518                 Ukiyo_e
#
#                                                                  painting  \
# 0                                            aaron-siskind_chicago-6-1961
# 1                                             aaron-siskind_feet-102-1957
# 2                                           aaron-siskind_kentucky-4-1951
# 3                                          aaron-siskind_new-york-24-1988
# 4                                    aaron-siskind_new-york-city-w-1-1947
# ...                                                                   ...
# 51514                                 utagawa-toyokuni_nakamura-utaemon-1
# 51515    utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798
# 51516                                      utagawa-toyokuni_the-promenade
# 51517  utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 51518                                utagawa-toyokuni_three-beauties-snow
#
#                     emotype
# 0                  negative
# 1                  negative
# 2                  negative
# 3                  negative
# 4                  negative
# ...                     ...
# 51514              negative
# 51515  [negative, positive]
# 51516  [negative, positive]
# 51517  [negative, positive]
# 51518              positive
#
# [51519 rows x 3 columns]

# %%
t=type(dfemo.emotype[51515])
dfemo=dfemo[dfemo["emotype"].apply(lambda x: type(x) !=t )].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 37875                 Ukiyo_e
# 37876                 Ukiyo_e
# 37877                 Ukiyo_e
# 37878                 Ukiyo_e
# 37879                 Ukiyo_e
#
#                                                                                                 painting  \
# 0                                                                           aaron-siskind_chicago-6-1961
# 1                                                                            aaron-siskind_feet-102-1957
# 2                                                                          aaron-siskind_kentucky-4-1951
# 3                                                                         aaron-siskind_new-york-24-1988
# 4                                                                   aaron-siskind_new-york-city-w-1-1947
# ...                                                                                                  ...
# 37875  utagawa-toyokuni_kabuki-actors-sanogawa-ichimatsu-ii-as-hayano-kampei-and-osagawa-tsuneyo-as-onoe
# 37876                        utagawa-toyokuni_nakamura-nosio-the-second-performs-the-dance-dodzedzi-1796
# 37877                                                                  utagawa-toyokuni_nakamura-utaemon
# 37878                                                                utagawa-toyokuni_nakamura-utaemon-1
# 37879                                                               utagawa-toyokuni_three-beauties-snow
#
#         emotype
# 0      negative
# 1      negative
# 2      negative
# 3      negative
# 4      negative
# ...         ...
# 37875  negative
# 37876  negative
# 37877  negative
# 37878  negative
# 37879  positive
#
# [37880 rows x 3 columns]

# %%
dfemo=dfemo[dfemo.emotype!="something else"].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 37875                 Ukiyo_e
# 37876                 Ukiyo_e
# 37877                 Ukiyo_e
# 37878                 Ukiyo_e
# 37879                 Ukiyo_e
#
#                                                                                                 painting  \
# 0                                                                           aaron-siskind_chicago-6-1961
# 1                                                                            aaron-siskind_feet-102-1957
# 2                                                                          aaron-siskind_kentucky-4-1951
# 3                                                                         aaron-siskind_new-york-24-1988
# 4                                                                   aaron-siskind_new-york-city-w-1-1947
# ...                                                                                                  ...
# 37875  utagawa-toyokuni_kabuki-actors-sanogawa-ichimatsu-ii-as-hayano-kampei-and-osagawa-tsuneyo-as-onoe
# 37876                        utagawa-toyokuni_nakamura-nosio-the-second-performs-the-dance-dodzedzi-1796
# 37877                                                                  utagawa-toyokuni_nakamura-utaemon
# 37878                                                                utagawa-toyokuni_nakamura-utaemon-1
# 37879                                                               utagawa-toyokuni_three-beauties-snow
#
#         emotype
# 0      negative
# 1      negative
# 2      negative
# 3      negative
# 4      negative
# ...         ...
# 37875  negative
# 37876  negative
# 37877  negative
# 37878  negative
# 37879  positive
#
# [37880 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 37875                 Ukiyo_e
# 37876                 Ukiyo_e
# 37877                 Ukiyo_e
# 37878                 Ukiyo_e
# 37879                 Ukiyo_e
#
#                                                                                                 painting  \
# 0                                                                           aaron-siskind_chicago-6-1961
# 1                                                                            aaron-siskind_feet-102-1957
# 2                                                                          aaron-siskind_kentucky-4-1951
# 3                                                                         aaron-siskind_new-york-24-1988
# 4                                                                   aaron-siskind_new-york-city-w-1-1947
# ...                                                                                                  ...
# 37875  utagawa-toyokuni_kabuki-actors-sanogawa-ichimatsu-ii-as-hayano-kampei-and-osagawa-tsuneyo-as-onoe
# 37876                        utagawa-toyokuni_nakamura-nosio-the-second-performs-the-dance-dodzedzi-1796
# 37877                                                                  utagawa-toyokuni_nakamura-utaemon
# 37878                                                                utagawa-toyokuni_nakamura-utaemon-1
# 37879                                                               utagawa-toyokuni_three-beauties-snow
#
#         emotype  \
# 0      negative
# 1      negative
# 2      negative
# 3      negative
# 4      negative
# ...         ...
# 37875  negative
# 37876  negative
# 37877  negative
# 37878  negative
# 37879  positive
#
#                                                                                                                                 path
# 0                                                            dataset\wikiart\Abstract_Expressionism\aaron-siskind_chicago-6-1961.jpg
# 1                                                             dataset\wikiart\Abstract_Expressionism\aaron-siskind_feet-102-1957.jpg
# 2                                                           dataset\wikiart\Abstract_Expressionism\aaron-siskind_kentucky-4-1951.jpg
# 3                                                          dataset\wikiart\Abstract_Expressionism\aaron-siskind_new-york-24-1988.jpg
# 4                                                    dataset\wikiart\Abstract_Expressionism\aaron-siskind_new-york-city-w-1-1947.jpg
# ...                                                                                                                              ...
# 37875  dataset\wikiart\Ukiyo_e\utagawa-toyokuni_kabuki-actors-sanogawa-ichimatsu-ii-as-hayano-kampei-and-osagawa-tsuneyo-as-onoe.jpg
# 37876                        dataset\wikiart\Ukiyo_e\utagawa-toyokuni_nakamura-nosio-the-second-performs-the-dance-dodzedzi-1796.jpg
# 37877                                                                  dataset\wikiart\Ukiyo_e\utagawa-toyokuni_nakamura-utaemon.jpg
# 37878                                                                dataset\wikiart\Ukiyo_e\utagawa-toyokuni_nakamura-utaemon-1.jpg
# 37879                                                               dataset\wikiart\Ukiyo_e\utagawa-toyokuni_three-beauties-snow.jpg
#
# [37880 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
frac=1-(dfemo.emotype.value_counts()[1]/dfemo.emotype.value_counts()[0])

# %%
dfemo = dfemo.drop(dfemo[dfemo['emotype'] == "negative"].sample(frac=frac).index)
dfemo
# Out:
#                     art_style  \
# 8      Abstract_Expressionism
# 18     Abstract_Expressionism
# 29     Abstract_Expressionism
# 34     Abstract_Expressionism
# 38     Abstract_Expressionism
# ...                       ...
# 37848                 Ukiyo_e
# 37851                 Ukiyo_e
# 37857                 Ukiyo_e
# 37872                 Ukiyo_e
# 37879                 Ukiyo_e
#
#                                                    painting   emotype  \
# 8                            aaron-siskind_the-tree-35-1973  positive
# 18                                 aki-kuroda_untitled-1988  negative
# 29                                  alice-baber_green-swing  negative
# 34                     alice-baber_red-yellow-and-blue-1960  negative
# 38     alma-woodsey-thomas_untitled-floral-abstraction-1970  positive
# ...                                                     ...       ...
# 37848                     utagawa-sadatora_beauty-strolling  positive
# 37851    utagawa-sadatora_fashionable-seven-autumn-plants-1  positive
# 37857           utagawa-sadatora_woman-under-flowering-tree  negative
# 37872               utagawa-toyokuni_chushingura-scene-1811  negative
# 37879                  utagawa-toyokuni_three-beauties-snow  positive
#
#                                                                                                   path
# 8                            dataset\wikiart\Abstract_Expressionism\aaron-siskind_the-tree-35-1973.jpg
# 18                                 dataset\wikiart\Abstract_Expressionism\aki-kuroda_untitled-1988.jpg
# 29                                  dataset\wikiart\Abstract_Expressionism\alice-baber_green-swing.jpg
# 34                     dataset\wikiart\Abstract_Expressionism\alice-baber_red-yellow-and-blue-1960.jpg
# 38     dataset\wikiart\Abstract_Expressionism\alma-woodsey-thomas_untitled-floral-abstraction-1970.jpg
# ...                                                                                                ...
# 37848                                    dataset\wikiart\Ukiyo_e\utagawa-sadatora_beauty-strolling.jpg
# 37851                   dataset\wikiart\Ukiyo_e\utagawa-sadatora_fashionable-seven-autumn-plants-1.jpg
# 37857                          dataset\wikiart\Ukiyo_e\utagawa-sadatora_woman-under-flowering-tree.jpg
# 37872                              dataset\wikiart\Ukiyo_e\utagawa-toyokuni_chushingura-scene-1811.jpg
# 37879                                 dataset\wikiart\Ukiyo_e\utagawa-toyokuni_three-beauties-snow.jpg
#
# [8258 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
for i in dfemo.path:
    try:
        im=Image.open(i)
    except:
        dfemo=dfemo.drop(dfemo[dfemo.path==i].index)
dfemo
# Out:
#                     art_style  \
# 8      Abstract_Expressionism
# 18     Abstract_Expressionism
# 29     Abstract_Expressionism
# 34     Abstract_Expressionism
# 38     Abstract_Expressionism
# ...                       ...
# 37848                 Ukiyo_e
# 37851                 Ukiyo_e
# 37857                 Ukiyo_e
# 37872                 Ukiyo_e
# 37879                 Ukiyo_e
#
#                                                    painting   emotype  \
# 8                            aaron-siskind_the-tree-35-1973  positive
# 18                                 aki-kuroda_untitled-1988  negative
# 29                                  alice-baber_green-swing  negative
# 34                     alice-baber_red-yellow-and-blue-1960  negative
# 38     alma-woodsey-thomas_untitled-floral-abstraction-1970  positive
# ...                                                     ...       ...
# 37848                     utagawa-sadatora_beauty-strolling  positive
# 37851    utagawa-sadatora_fashionable-seven-autumn-plants-1  positive
# 37857           utagawa-sadatora_woman-under-flowering-tree  negative
# 37872               utagawa-toyokuni_chushingura-scene-1811  negative
# 37879                  utagawa-toyokuni_three-beauties-snow  positive
#
#                                                                                                   path
# 8                            dataset\wikiart\Abstract_Expressionism\aaron-siskind_the-tree-35-1973.jpg
# 18                                 dataset\wikiart\Abstract_Expressionism\aki-kuroda_untitled-1988.jpg
# 29                                  dataset\wikiart\Abstract_Expressionism\alice-baber_green-swing.jpg
# 34                     dataset\wikiart\Abstract_Expressionism\alice-baber_red-yellow-and-blue-1960.jpg
# 38     dataset\wikiart\Abstract_Expressionism\alma-woodsey-thomas_untitled-floral-abstraction-1970.jpg
# ...                                                                                                ...
# 37848                                    dataset\wikiart\Ukiyo_e\utagawa-sadatora_beauty-strolling.jpg
# 37851                   dataset\wikiart\Ukiyo_e\utagawa-sadatora_fashionable-seven-autumn-plants-1.jpg
# 37857                          dataset\wikiart\Ukiyo_e\utagawa-sadatora_woman-under-flowering-tree.jpg
# 37872                              dataset\wikiart\Ukiyo_e\utagawa-toyokuni_chushingura-scene-1811.jpg
# 37879                                 dataset\wikiart\Ukiyo_e\utagawa-toyokuni_three-beauties-snow.jpg
#
# [8191 rows x 4 columns]

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotype'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
opt_func = partial(ranger)
model=xresnet34_deeper
learn = vision_learner(dls, model,loss_func=fastai.losses.FocalLossFlat(),pretrained=False, metrics=error_rate,opt_func=opt_func)

# %%
lr=learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lr=lr[2]

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='artemis2_classification_model_xresnet34_deeper_refined_beforemode_balanced_binary_focal', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.171650</td>
#       <td>0.174018</td>
#       <td>0.446004</td>
#       <td>04:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.172417</td>
#       <td>0.172651</td>
#       <td>0.461867</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.173919</td>
#       <td>0.195823</td>
#       <td>0.521049</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.173212</td>
#       <td>0.170704</td>
#       <td>0.420988</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.173730</td>
#       <td>0.171347</td>
#       <td>0.441123</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.174126</td>
#       <td>0.170093</td>
#       <td>0.416717</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.172768</td>
#       <td>0.170666</td>
#       <td>0.444783</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.174098</td>
#       <td>0.174186</td>
#       <td>0.416717</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.174080</td>
#       <td>0.175003</td>
#       <td>0.460037</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.170143</td>
#       <td>0.181124</td>
#       <td>0.423429</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.171986</td>
#       <td>0.170565</td>
#       <td>0.428920</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.172049</td>
#       <td>0.176845</td>
#       <td>0.428920</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.174113</td>
#       <td>0.169838</td>
#       <td>0.427090</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.172294</td>
#       <td>0.169172</td>
#       <td>0.417328</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.171737</td>
#       <td>0.171156</td>
#       <td>0.426480</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.172278</td>
#       <td>0.183470</td>
#       <td>0.425869</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.172064</td>
#       <td>0.171594</td>
#       <td>0.420378</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.172821</td>
#       <td>0.170189</td>
#       <td>0.436852</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.172712</td>
#       <td>0.171087</td>
#       <td>0.436242</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.170741</td>
#       <td>0.292378</td>
#       <td>0.448444</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.171387</td>
#       <td>0.192767</td>
#       <td>0.433801</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.172170</td>
#       <td>0.189530</td>
#       <td>0.450275</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.171506</td>
#       <td>0.343634</td>
#       <td>0.428920</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.171563</td>
#       <td>0.188750</td>
#       <td>0.425869</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.171268</td>
#       <td>0.170206</td>
#       <td>0.424649</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.169211</td>
#       <td>0.518721</td>
#       <td>0.422819</td>
#       <td>04:06</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.166238</td>
#       <td>0.187330</td>
#       <td>0.413057</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.164698</td>
#       <td>0.840760</td>
#       <td>0.422209</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.166723</td>
#       <td>0.643636</td>
#       <td>0.416717</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.165322</td>
#       <td>0.294209</td>
#       <td>0.422209</td>
#       <td>04:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.1740175187587738.
# Better model found at epoch 1 with valid_loss value: 0.17265060544013977.
# Better model found at epoch 3 with valid_loss value: 0.17070400714874268.
# Better model found at epoch 5 with valid_loss value: 0.1700931340456009.
# Better model found at epoch 12 with valid_loss value: 0.16983824968338013.
# Better model found at epoch 13 with valid_loss value: 0.1691715568304062.

# %%
model=learn.load('artemis2_classification_model_xresnet34_deeper_refined_beforemode_balanced_binary_focal')
# Out:
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py:58: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
interp=ClassificationInterpretation(model,dls.valid,model.loss_func)

# %%
interp.plot_confusion_matrix(cmap="Dark2")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#     negative       0.56      0.65      0.60       830
#     positive       0.57      0.48      0.53       808
#
#     accuracy                           0.57      1638
#    macro avg       0.57      0.57      0.56      1638
# weighted avg       0.57      0.57      0.57      1638

# %%
dfemo.emotype.value_counts()

# %%
model.loss_func
