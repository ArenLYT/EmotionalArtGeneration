# %%
from fastai.data.all import *
from fastai.vision.all import *
import fastai
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion
# 0       something else
# 1              sadness
# 2       something else
# 3          contentment
# 4                  awe
# ...                ...
# 454679             awe
# 454680             awe
# 454681      excitement
# 454682     contentment
# 454683            fear
#
# [454684 rows x 3 columns]

# %%
processed=df.groupby(["art_style","painting"])["emotion"].agg(pd.Series.mode).reset_index()
processed
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                                aaron-siskind_feet-102-1957
# 4                                          aaron-siskind_gloucester-16a-1944
# ...                                                                      ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
# 80029     utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 80030                                   utagawa-toyokuni_three-beauties-snow
#
#                              emotion
# 0                               fear
# 1                               fear
# 2                               fear
# 3          [disgust, something else]
# 4                     something else
# ...                              ...
# 80026                           fear
# 80027                    contentment
# 80028                    contentment
# 80029             [awe, contentment]
# 80030  [contentment, something else]
#
# [80031 rows x 3 columns]

# %%
t=type(processed.emotion[3])
processed2=processed[processed["emotion"].apply(lambda x: type(x) !=t )]
processed2
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 4      Abstract_Expressionism
# 6      Abstract_Expressionism
# ...                       ...
# 80024                 Ukiyo_e
# 80025                 Ukiyo_e
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 4                                          aaron-siskind_gloucester-16a-1944
# 6                                              aaron-siskind_kentucky-4-1951
# ...                                                                      ...
# 80024       utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798
# 80025                                          utagawa-toyokuni_seki-sanjuro
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
#
#               emotion
# 0                fear
# 1                fear
# 2                fear
# 4      something else
# 6      something else
# ...               ...
# 80024       amusement
# 80025             awe
# 80026            fear
# 80027     contentment
# 80028     contentment
#
# [59669 rows x 3 columns]

# %%
processed2=processed2.reset_index()
processed2
# Out:
#        index               art_style  \
# 0          0  Abstract_Expressionism
# 1          1  Abstract_Expressionism
# 2          2  Abstract_Expressionism
# 3          4  Abstract_Expressionism
# 4          6  Abstract_Expressionism
# ...      ...                     ...
# 59664  80024                 Ukiyo_e
# 59665  80025                 Ukiyo_e
# 59666  80026                 Ukiyo_e
# 59667  80027                 Ukiyo_e
# 59668  80028                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                          aaron-siskind_gloucester-16a-1944
# 4                                              aaron-siskind_kentucky-4-1951
# ...                                                                      ...
# 59664       utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798
# 59665                                          utagawa-toyokuni_seki-sanjuro
# 59666  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 59667                                    utagawa-toyokuni_the-heian-courtier
# 59668                                         utagawa-toyokuni_the-promenade
#
#               emotion
# 0                fear
# 1                fear
# 2                fear
# 3      something else
# 4      something else
# ...               ...
# 59664       amusement
# 59665             awe
# 59666            fear
# 59667     contentment
# 59668     contentment
#
# [59669 rows x 4 columns]

# %%
processed2['path']= processed2.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
processed2
# Out:
#        index               art_style  \
# 0          0  Abstract_Expressionism
# 1          1  Abstract_Expressionism
# 2          2  Abstract_Expressionism
# 3          4  Abstract_Expressionism
# 4          6  Abstract_Expressionism
# ...      ...                     ...
# 59664  80024                 Ukiyo_e
# 59665  80025                 Ukiyo_e
# 59666  80026                 Ukiyo_e
# 59667  80027                 Ukiyo_e
# 59668  80028                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                          aaron-siskind_gloucester-16a-1944
# 4                                              aaron-siskind_kentucky-4-1951
# ...                                                                      ...
# 59664       utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798
# 59665                                          utagawa-toyokuni_seki-sanjuro
# 59666  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 59667                                    utagawa-toyokuni_the-heian-courtier
# 59668                                         utagawa-toyokuni_the-promenade
#
#               emotion  \
# 0                fear
# 1                fear
# 2                fear
# 3      something else
# 4      something else
# ...               ...
# 59664       amusement
# 59665             awe
# 59666            fear
# 59667     contentment
# 59668     contentment
#
#                                                                                                     path
# 0                                dataset\wikiart\Abstract_Expressionism\aaron-siskind_acolman-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aaron-siskind_chicago-1951.jpg
# 2                                dataset\wikiart\Abstract_Expressionism\aaron-siskind_chicago-6-1961.jpg
# 3                           dataset\wikiart\Abstract_Expressionism\aaron-siskind_gloucester-16a-1944.jpg
# 4                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_kentucky-4-1951.jpg
# ...                                                                                                  ...
# 59664       dataset\wikiart\Ukiyo_e\utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798.jpg
# 59665                                          dataset\wikiart\Ukiyo_e\utagawa-toyokuni_seki-sanjuro.jpg
# 59666  dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen.jpg
# 59667                                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-heian-courtier.jpg
# 59668                                         dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-promenade.jpg
#
# [59669 rows x 5 columns]

# %%
for i in processed2.path:
    try:
        im=Image.open(i)
    except:
        processed2=processed2.drop(processed2[processed2.path==i].index)
# Out:
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\PIL\Image.py:3035: DecompressionBombWarning: Image size (107327830 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
processed2
# Out:
#        index               art_style  \
# 0          0  Abstract_Expressionism
# 1          1  Abstract_Expressionism
# 2          2  Abstract_Expressionism
# 3          4  Abstract_Expressionism
# 4          6  Abstract_Expressionism
# ...      ...                     ...
# 59664  80024                 Ukiyo_e
# 59665  80025                 Ukiyo_e
# 59666  80026                 Ukiyo_e
# 59667  80027                 Ukiyo_e
# 59668  80028                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                          aaron-siskind_gloucester-16a-1944
# 4                                              aaron-siskind_kentucky-4-1951
# ...                                                                      ...
# 59664       utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798
# 59665                                          utagawa-toyokuni_seki-sanjuro
# 59666  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 59667                                    utagawa-toyokuni_the-heian-courtier
# 59668                                         utagawa-toyokuni_the-promenade
#
#               emotion  \
# 0                fear
# 1                fear
# 2                fear
# 3      something else
# 4      something else
# ...               ...
# 59664       amusement
# 59665             awe
# 59666            fear
# 59667     contentment
# 59668     contentment
#
#                                                                                                     path
# 0                                dataset\wikiart\Abstract_Expressionism\aaron-siskind_acolman-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aaron-siskind_chicago-1951.jpg
# 2                                dataset\wikiart\Abstract_Expressionism\aaron-siskind_chicago-6-1961.jpg
# 3                           dataset\wikiart\Abstract_Expressionism\aaron-siskind_gloucester-16a-1944.jpg
# 4                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_kentucky-4-1951.jpg
# ...                                                                                                  ...
# 59664       dataset\wikiart\Ukiyo_e\utagawa-toyokuni_segawa-kikunojo-iii-and-bando-mitsugoro-ii-1798.jpg
# 59665                                          dataset\wikiart\Ukiyo_e\utagawa-toyokuni_seki-sanjuro.jpg
# 59666  dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen.jpg
# 59667                                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-heian-courtier.jpg
# 59668                                         dataset\wikiart\Ukiyo_e\utagawa-toyokuni_the-promenade.jpg
#
# [59668 rows x 5 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(processed2.emotion,bins=range(0,10), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
plt.figure(figsize=(100,20))
plt.hist(processed.art_style,bins=range(0,28), rwidth=0.8,align="left")
plt.title('Histogram of Art Style')
# Out:
# Text(0.5, 1.0, 'Histogram of Art Style')

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotion'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(processed2,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
opt_func = partial(ranger)
model=xresnet34_deeper
learn = vision_learner(dls, model,pretrained=False, metrics=error_rate,opt_func=opt_func)

# %%
lr=learn.lr_find(suggest_funcs=(valley))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='classification_model_xresnet34_deeper', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.00% [3/30 2:43:20&lt;24:30:03]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.782968</td>
#       <td>628.524902</td>
#       <td>42:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.765235</td>
#       <td>318.964569</td>
#       <td>59:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.807082</td>
#       <td>1076.010132</td>
#       <td>1:01:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='38' class='' max='2550' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.49% [38/2550 00:42&lt;46:50 1.7720]
#     </div>
# Better model found at epoch 0 with valid_loss value: 628.52490234375.
# Better model found at epoch 1 with valid_loss value: 318.9645690917969.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11616\1754860271.py in <module>
# ----> 1 learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss',
#       2                                                                   comp=None,
#       3                                                                   min_delta=0.0,
#       4                                                                   fname='classification_model_xresnet34_deeper',
#       5                                                                   every_epoch=False,
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\callback\schedule.py in fit_flat_cos(self, n_epoch, lr, div_final, pct_start, wd, cbs, reset_opt, start_epoch)
#     140     lr = np.array([h['lr'] for h in self.opt.hypers])
#     141     scheds = {'lr': combined_cos(pct_start, lr, lr, lr/div_final)}
# --> 142     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd, start_epoch=0)
#     143
#     144 # %% ../nbs/14_callback.schedule.ipynb 58
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     254             self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     255             self.n_epoch = n_epoch
# --> 256             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     257
#     258     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     191
#     192     def _with_events(self, f, event_type, ex, final=noop):
# --> 193         try: self(f'before_{event_type}');  f()
#     194         except ex: self(f'after_cancel_{event_type}')
#     195         self(f'after_{event_type}');  final()
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _do_fit(self)
#     243         for epoch in range(self.n_epoch):
#     244             self.epoch=epoch
# --> 245             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     246
#     247     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False, start_epoch=0):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     191
#     192     def _with_events(self, f, event_type, ex, final=noop):
# --> 193         try: self(f'before_{event_type}');  f()
#     194         except ex: self(f'after_cancel_{event_type}')
#     195         self(f'after_{event_type}');  final()
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _do_epoch(self)
#     237
#     238     def _do_epoch(self):
# --> 239         self._do_epoch_train()
#     240         self._do_epoch_validate()
#     241
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _do_epoch_train(self)
#     229     def _do_epoch_train(self):
#     230         self.dl = self.dls.train
# --> 231         self._with_events(self.all_batches, 'train', CancelTrainException)
#     232
#     233     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in _with_events(self, f, event_type, ex, final)
#     191
#     192     def _with_events(self, f, event_type, ex, final=noop):
# --> 193         try: self(f'before_{event_type}');  f()
#     194         except ex: self(f'after_cancel_{event_type}')
#     195         self(f'after_{event_type}');  final()
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py in all_batches(self)
#     197     def all_batches(self):
#     198         self.n_iter = len(self.dl)
# --> 199         for o in enumerate(self.dl): self.one_batch(*o)
#     200
#     201     def _backward(self): self.loss_grad.backward()
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\load.py in __iter__(self)
#     127         self.before_iter()
#     128         self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 129         for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     130             # pin_memory causes tuples to be converted to lists, so convert them back to tuples
#     131             if self.pin_memory and type(b) == list: b = tuple(b)
#
# ~\anaconda3\envs\cupy\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\envs\cupy\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~\anaconda3\envs\cupy\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      37                 raise StopIteration
#      38         else:
# ---> 39             data = next(self.dataset_iter)
#      40         return self.collate_fn(data)
#      41
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\load.py in create_batches(self, samps)
#     138         if self.dataset is not None: self.it = iter(self.dataset)
#     139         res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 140         yield from map(self.do_batch, self.chunkify(res))
#     141
#     142     def new(self, dataset=None, cls=None, **kwargs):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\basics.py in chunked(it, chunk_sz, drop_last, n_chunks)
#     223     if not isinstance(it, Iterator): it = iter(it)
#     224     while True:
# --> 225         res = list(itertools.islice(it, chunk_sz))
#     226         if res and (len(res)==chunk_sz or not drop_last): yield res
#     227         if len(res)<chunk_sz: return
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\load.py in do_item(self, s)
#     153     def prebatched(self): return self.bs is None
#     154     def do_item(self, s):
# --> 155         try: return self.after_item(self.create_item(s))
#     156         except SkipItemException: return None
#     157     def chunkify(self, b): return b if self.prebatched else chunked(b, self.bs, self.drop_last)
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\load.py in create_item(self, s)
#     160     def retain(self, res, b):  return retain_types(res, b[0] if is_listy(b) else b)
#     161     def create_item(self, s):
# --> 162         if self.indexed: return self.dataset[s or 0]
#     163         elif s is None:  return next(self.it)
#     164         else: raise IndexError("Cannot index an iterable dataset numerically - must use `None`.")
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\core.py in __getitem__(self, it)
#     453
#     454     def __getitem__(self, it):
# --> 455         res = tuple([tl[it] for tl in self.tls])
#     456         return res if is_indexer(it) else list(zip(*res))
#     457
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\core.py in <listcomp>(.0)
#     453
#     454     def __getitem__(self, it):
# --> 455         res = tuple([tl[it] for tl in self.tls])
#     456         return res if is_indexer(it) else list(zip(*res))
#     457
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\core.py in __getitem__(self, idx)
#     412         res = super().__getitem__(idx)
#     413         if self._after_item is None: return res
# --> 414         return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#     415
#     416 # %% ../nbs/03_data.core.ipynb 54
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\data\core.py in _after_item(self, o)
#     372             raise
#     373     def subset(self, i): return self._new(self._get(self.splits[i]), split_idx=i)
# --> 374     def _after_item(self, o): return self.tfms(o)
#     375     def __repr__(self): return f"{self.__class__.__name__}: {self.items}\ntfms - {self.tfms.fs}"
#     376     def __iter__(self): return (self[i] for i in range(len(self)))
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\transform.py in __call__(self, o)
#     206         self.fs = self.fs.sorted(key='order')
#     207
# --> 208     def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     209     def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     210     def __getitem__(self,i): return self.fs[i]
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\transform.py in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     156     for f in tfms:
#     157         if not is_enc: f = f.decode
# --> 158         x = f(x, **kwargs)
#     159     return x
#     160
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\transform.py in __call__(self, x, **kwargs)
#      79     @property
#      80     def name(self): return getattr(self, '_name', _get_name(self))
# ---> 81     def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#      82     def decode  (self, x, **kwargs): return self._call('decodes', x, **kwargs)
#      83     def __repr__(self): return f'{self.name}:\nencodes: {self.encodes}decodes: {self.decodes}'
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\transform.py in _call(self, fn, x, split_idx, **kwargs)
#      89     def _call(self, fn, x, split_idx=None, **kwargs):
#      90         if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 91         return self._do_call(getattr(self, fn), x, **kwargs)
#      92
#      93     def _do_call(self, f, x, **kwargs):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\transform.py in _do_call(self, f, x, **kwargs)
#      95             if f is None: return x
#      96             ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 97             return retain_type(f(x, **kwargs), x, ret)
#      98         res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      99         return retain_type(res, x)
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastcore\dispatch.py in __call__(self, *args, **kwargs)
#     118         elif self.inst is not None: f = MethodType(f, self.inst)
#     119         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 120         return f(*args, **kwargs)
#     121
#     122     def __get__(self, inst, owner):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\vision\core.py in create(cls, fn, **kwargs)
#     121         if isinstance(fn,ndarray): return cls(Image.fromarray(fn))
#     122         if isinstance(fn,bytes): fn = io.BytesIO(fn)
# --> 123         return cls(load_image(fn, **merge(cls._open_args, kwargs)))
#     124
#     125     def show(self, ctx=None, **kwargs):
#
# ~\anaconda3\envs\cupy\lib\site-packages\fastai\vision\core.py in load_image(fn, mode)
#      96 def load_image(fn, mode=None):
#      97     "Open and load a `PIL.Image` and convert to `mode`"
# ---> 98     im = Image.open(fn)
#      99     im.load()
#     100     im = im._new(im.im)
#
# ~\anaconda3\envs\cupy\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3090
#    3091     if filename:
# -> 3092         fp = builtins.open(filename, "rb")
#    3093         exclusive_fp = True
#    3094
#
# KeyboardInterrupt:
