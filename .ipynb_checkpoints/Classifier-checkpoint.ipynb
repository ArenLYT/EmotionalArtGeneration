# %%
from fastai.data.all import *
from fastai.vision.all import *
import fastai
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition
# 0       something else          10
# 1              sadness          10
# 2       something else          10
# 3          contentment          10
# 4                  awe          10
# ...                ...         ...
# 454679             awe          48
# 454680             awe           8
# 454681      excitement           8
# 454682     contentment           8
# 454683            fear          10
#
# [454684 rows x 4 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*0.8 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
dfemo=df

dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()

dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                                aaron-siskind_feet-102-1957
# 4                                          aaron-siskind_gloucester-16a-1944
# ...                                                                      ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
# 80029     utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 80030                                   utagawa-toyokuni_three-beauties-snow
#
#                                       emotion
# 0         [fear, contentment, something else]
# 1             [fear, sadness, something else]
# 2                      [fear, something else]
# 3      [something else, disgust, contentment]
# 4                              something else
# ...                                       ...
# 80026          [fear, amusement, contentment]
# 80027      [contentment, disgust, excitement]
# 80028      [contentment, excitement, sadness]
# 80029      [contentment, awe, something else]
# 80030      [something else, contentment, awe]
#
# [80031 rows x 3 columns]

# %%
t=type(dfemo.emotion[0])
dfemo=dfemo[dfemo["emotion"].apply(lambda x: type(x) !=t )].reset_index()
dfemo
# Out:
#       index               art_style  \
# 0         4  Abstract_Expressionism
# 1        11  Abstract_Expressionism
# 2        19  Abstract_Expressionism
# 3        24  Abstract_Expressionism
# 4        74  Abstract_Expressionism
# ...     ...                     ...
# 9163  79940                 Ukiyo_e
# 9164  79947                 Ukiyo_e
# 9165  79998                 Ukiyo_e
# 9166  80005                 Ukiyo_e
# 9167  80007                 Ukiyo_e
#
#                                                                                  painting  \
# 0                                                       aaron-siskind_gloucester-16a-1944
# 1                                                    aaron-siskind_new-york-city-w-1-1947
# 2                                                              aaron-siskind_utah-84-1976
# 3                                                                abidin-dino_antibes-1961
# 4                                                            alice-baber_red-passage-1966
# ...                                                                                   ...
# 9163                                                           utagawa-kuniyoshi_women-19
# 9164                                                           utagawa-kuniyoshi_women-25
# 9165                                    utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 9166  utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura
# 9167                utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#              emotion
# 0     something else
# 1               fear
# 2               fear
# 3     something else
# 4        contentment
# ...              ...
# 9163     contentment
# 9164     contentment
# 9165     contentment
# 9166     contentment
# 9167     contentment
#
# [9168 rows x 4 columns]

# %%
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                    art_style  \
# 0     Abstract_Expressionism
# 1     Abstract_Expressionism
# 2     Abstract_Expressionism
# 3     Abstract_Expressionism
# 4     Abstract_Expressionism
# ...                      ...
# 9163                 Ukiyo_e
# 9164                 Ukiyo_e
# 9165                 Ukiyo_e
# 9166                 Ukiyo_e
# 9167                 Ukiyo_e
#
#                                                                                  painting  \
# 0                                                       aaron-siskind_gloucester-16a-1944
# 1                                                    aaron-siskind_new-york-city-w-1-1947
# 2                                                              aaron-siskind_utah-84-1976
# 3                                                                abidin-dino_antibes-1961
# 4                                                            alice-baber_red-passage-1966
# ...                                                                                   ...
# 9163                                                           utagawa-kuniyoshi_women-19
# 9164                                                           utagawa-kuniyoshi_women-25
# 9165                                    utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 9166  utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura
# 9167                utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#              emotion
# 0     something else
# 1               fear
# 2               fear
# 3     something else
# 4        contentment
# ...              ...
# 9163     contentment
# 9164     contentment
# 9165     contentment
# 9166     contentment
# 9167     contentment
#
# [9168 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                    art_style  \
# 0     Abstract_Expressionism
# 1     Abstract_Expressionism
# 2     Abstract_Expressionism
# 3     Abstract_Expressionism
# 4     Abstract_Expressionism
# ...                      ...
# 9163                 Ukiyo_e
# 9164                 Ukiyo_e
# 9165                 Ukiyo_e
# 9166                 Ukiyo_e
# 9167                 Ukiyo_e
#
#                                                                                  painting  \
# 0                                                       aaron-siskind_gloucester-16a-1944
# 1                                                    aaron-siskind_new-york-city-w-1-1947
# 2                                                              aaron-siskind_utah-84-1976
# 3                                                                abidin-dino_antibes-1961
# 4                                                            alice-baber_red-passage-1966
# ...                                                                                   ...
# 9163                                                           utagawa-kuniyoshi_women-19
# 9164                                                           utagawa-kuniyoshi_women-25
# 9165                                    utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 9166  utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura
# 9167                utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#              emotion  \
# 0     something else
# 1               fear
# 2               fear
# 3     something else
# 4        contentment
# ...              ...
# 9163     contentment
# 9164     contentment
# 9165     contentment
# 9166     contentment
# 9167     contentment
#
#                                                                                                                  path
# 0                                        dataset\wikiart\Abstract_Expressionism\aaron-siskind_gloucester-16a-1944.jpg
# 1                                     dataset\wikiart\Abstract_Expressionism\aaron-siskind_new-york-city-w-1-1947.jpg
# 2                                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_utah-84-1976.jpg
# 3                                                 dataset\wikiart\Abstract_Expressionism\abidin-dino_antibes-1961.jpg
# 4                                             dataset\wikiart\Abstract_Expressionism\alice-baber_red-passage-1966.jpg
# ...                                                                                                               ...
# 9163                                                           dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-19.jpg
# 9164                                                           dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-25.jpg
# 9165                                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata.jpg
# 9166  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura.jpg
# 9167                dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
#
# [9168 rows x 4 columns]

# %%
for i in dfemo.path:
    try:
        im=Image.open(i)
    except:
        dfemo=dfemo.drop(dfemo[dfemo.path==i].index)
dfemo
# Out:
#                    art_style  \
# 0     Abstract_Expressionism
# 1     Abstract_Expressionism
# 2     Abstract_Expressionism
# 3     Abstract_Expressionism
# 4     Abstract_Expressionism
# ...                      ...
# 9163                 Ukiyo_e
# 9164                 Ukiyo_e
# 9165                 Ukiyo_e
# 9166                 Ukiyo_e
# 9167                 Ukiyo_e
#
#                                                                                  painting  \
# 0                                                       aaron-siskind_gloucester-16a-1944
# 1                                                    aaron-siskind_new-york-city-w-1-1947
# 2                                                              aaron-siskind_utah-84-1976
# 3                                                                abidin-dino_antibes-1961
# 4                                                            alice-baber_red-passage-1966
# ...                                                                                   ...
# 9163                                                           utagawa-kuniyoshi_women-19
# 9164                                                           utagawa-kuniyoshi_women-25
# 9165                                    utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 9166  utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura
# 9167                utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#              emotion  \
# 0     something else
# 1               fear
# 2               fear
# 3     something else
# 4        contentment
# ...              ...
# 9163     contentment
# 9164     contentment
# 9165     contentment
# 9166     contentment
# 9167     contentment
#
#                                                                                                                  path
# 0                                        dataset\wikiart\Abstract_Expressionism\aaron-siskind_gloucester-16a-1944.jpg
# 1                                     dataset\wikiart\Abstract_Expressionism\aaron-siskind_new-york-city-w-1-1947.jpg
# 2                                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_utah-84-1976.jpg
# 3                                                 dataset\wikiart\Abstract_Expressionism\abidin-dino_antibes-1961.jpg
# 4                                             dataset\wikiart\Abstract_Expressionism\alice-baber_red-passage-1966.jpg
# ...                                                                                                               ...
# 9163                                                           dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-19.jpg
# 9164                                                           dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-25.jpg
# 9165                                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata.jpg
# 9166  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_view-of-mountains-of-awa-province-from-tsurugaoka-near-kamakura.jpg
# 9167                dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
#
# [9168 rows x 4 columns]

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotion'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
opt_func = partial(ranger)
model=xresnet34_deeper
learn = vision_learner(dls, model,pretrained=False, metrics=error_rate,opt_func=opt_func)

# %%
lr=learn.lr_find(suggest_funcs=(valley))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='classification_model_xresnet34_deeper_refined', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='17' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.67% [17/30 1:21:26&lt;1:02:17]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.643082</td>
#       <td>1.486751</td>
#       <td>0.465357</td>
#       <td>04:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.617417</td>
#       <td>1.988255</td>
#       <td>0.417349</td>
#       <td>04:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.448572</td>
#       <td>1.526688</td>
#       <td>0.417349</td>
#       <td>04:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.487532</td>
#       <td>1.360301</td>
#       <td>0.420076</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.323257</td>
#       <td>1.431455</td>
#       <td>0.416803</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.362247</td>
#       <td>1.283860</td>
#       <td>0.425532</td>
#       <td>04:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.301698</td>
#       <td>1.295479</td>
#       <td>0.410256</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.341693</td>
#       <td>1.426701</td>
#       <td>0.434806</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.313647</td>
#       <td>1.415712</td>
#       <td>0.414621</td>
#       <td>04:40</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.329372</td>
#       <td>1.299713</td>
#       <td>0.417894</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.293812</td>
#       <td>1.306210</td>
#       <td>0.431533</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.213432</td>
#       <td>1.516271</td>
#       <td>0.400436</td>
#       <td>04:57</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.267531</td>
#       <td>5.304768</td>
#       <td>0.418440</td>
#       <td>04:50</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.239153</td>
#       <td>13.327603</td>
#       <td>0.412439</td>
#       <td>04:49</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.214119</td>
#       <td>1.305824</td>
#       <td>0.402619</td>
#       <td>04:50</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.207922</td>
#       <td>25.840464</td>
#       <td>0.407529</td>
#       <td>04:52</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.182571</td>
#       <td>1.169021</td>
#       <td>0.402619</td>
#       <td>04:48</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='11' class='' max='115' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.57% [11/115 00:05&lt;00:55 1.2002]
#     </div>
# Better model found at epoch 0 with valid_loss value: 1.4867511987686157.
# Better model found at epoch 3 with valid_loss value: 1.3603013753890991.
# Better model found at epoch 5 with valid_loss value: 1.2838596105575562.
# Better model found at epoch 16 with valid_loss value: 1.169021487236023.

# %%
model=learn.load('classification_model_xresnet34_deeper_refined')

# %%
p=model.get_preds(with_input=True)
