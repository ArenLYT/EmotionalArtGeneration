# %%
from fastai.data.all import *
from fastai.vision.all import *
import fastai
import pandas as pd
import statistics
import matplotlib.pyplot as plt
from torchvision import models
import torch.nn as nn

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition
# 0       something else          10
# 1              sadness          10
# 2       something else          10
# 3          contentment          10
# 4                  awe          10
# ...                ...         ...
# 454679             awe          48
# 454680             awe           8
# 454681      excitement           8
# 454682     contentment           8
# 454683            fear          10
#
# [454684 rows x 4 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*1.0 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
def emtype(x):
    if x.emotion=='sadness':
        return "negative"
    elif x.emotion=='fear':
        return "negative"
    elif x.emotion=='disgust':
        return "negative"
    elif x.emotion=='anger':
        return "negative"
    elif x.emotion=='contentment':
        return "positive"
    elif x.emotion=='awe':
        return "positive"
    elif x.emotion=='amusement':
        return "positive"
    elif x.emotion=='excitement':
        return "positive"
    else:
        return "something else"

# %%
dfemo=df
dfemo['emotype']= dfemo.apply(emtype,axis=1)
dfemo
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition         emotype
# 0       something else          10  something else
# 1              sadness          10        negative
# 2       something else          10  something else
# 3          contentment          10        positive
# 4                  awe          10        positive
# ...                ...         ...             ...
# 454679             awe          48        positive
# 454680             awe           8        positive
# 454681      excitement           8        positive
# 454682     contentment           8        positive
# 454683            fear          10        negative
#
# [454684 rows x 5 columns]

# %%
#dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()
#dfemo

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotype"].agg(modo).reset_index()
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                                aaron-siskind_feet-102-1957
# 4                                          aaron-siskind_gloucester-16a-1944
# ...                                                                      ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
# 80029     utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 80030                                   utagawa-toyokuni_three-beauties-snow
#
#                                     emotype
# 0      [positive, negative, something else]
# 1      [negative, positive, something else]
# 2                [negative, something else]
# 3      [something else, negative, positive]
# 4                [something else, negative]
# ...                                     ...
# 80026                  [positive, negative]
# 80027                  [positive, negative]
# 80028                  [positive, negative]
# 80029            [positive, something else]
# 80030            [positive, something else]
#
# [80031 rows x 3 columns]

# %%
t=type(dfemo.emotype[0])
dfemo=dfemo[dfemo["emotype"].apply(lambda x: type(x) !=t )].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16754                 Ukiyo_e
# 16755                 Ukiyo_e
# 16756                 Ukiyo_e
# 16757                 Ukiyo_e
# 16758                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16754                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16755     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16756                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16757  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16758                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16754  positive
# 16755  positive
# 16756  positive
# 16757  positive
# 16758  positive
#
# [16759 rows x 3 columns]

# %%
dfemo=dfemo[dfemo.emotype!="something else"].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
# [16744 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype  \
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
#                                                                                                     path
# 0                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 2                                    dataset\wikiart\Abstract_Expressionism\alexander-calder_the-dog.jpg
# 3                     dataset\wikiart\Abstract_Expressionism\alice-baber_abstract-composition-1969-1.jpg
# 4                        dataset\wikiart\Abstract_Expressionism\alice-baber_lord-of-the-rainbow-1976.jpg
# ...                                                                                                  ...
# 16739                      dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata.jpg
# 16740     dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono.jpg
# 16741                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_view-of-oshima-from-atami-beach.jpg
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
# 16743                                                 dataset\wikiart\Ukiyo_e\utagawa-toyokuni_dance.jpg
#
# [16744 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
frac=1-(dfemo.emotype.value_counts()[1]/dfemo.emotype.value_counts()[0])

# %%
dfemo = dfemo.drop(dfemo[dfemo['emotype'] == "positive"].sample(frac=frac).index)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 7      Abstract_Expressionism
# 11     Abstract_Expressionism
# 19     Abstract_Expressionism
# ...                       ...
# 16719                 Ukiyo_e
# 16723                 Ukiyo_e
# 16726                 Ukiyo_e
# 16734                 Ukiyo_e
# 16742                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 7                                              alice-baber_wheel-of-day-1971
# 11                                                    atsuko-tanaka_93e-1993
# 19                                                brice-marden_untitled-1996
# ...                                                                      ...
# 16719                 utagawa-kuniyoshi_woman-doing-her-laundry-in-the-river
# 16723                                             utagawa-kuniyoshi_women-12
# 16726                                             utagawa-kuniyoshi_women-19
# 16734             utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#         emotype  \
# 0      negative
# 1      negative
# 7      positive
# 11     negative
# 19     positive
# ...         ...
# 16719  positive
# 16723  positive
# 16726  positive
# 16734  positive
# 16742  positive
#
#                                                                                                     path
# 0                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 7                               dataset\wikiart\Abstract_Expressionism\alice-baber_wheel-of-day-1971.jpg
# 11                                     dataset\wikiart\Abstract_Expressionism\atsuko-tanaka_93e-1993.jpg
# 19                                 dataset\wikiart\Abstract_Expressionism\brice-marden_untitled-1996.jpg
# ...                                                                                                  ...
# 16719                 dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_woman-doing-her-laundry-in-the-river.jpg
# 16723                                             dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-12.jpg
# 16726                                             dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-19.jpg
# 16734             dataset\wikiart\Ukiyo_e\utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship.jpg
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
#
# [3666 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
for i in dfemo.path:
    try:
        im=Image.open(i)
    except:
        dfemo=dfemo.drop(dfemo[dfemo.path==i].index)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 7      Abstract_Expressionism
# 11     Abstract_Expressionism
# 19     Abstract_Expressionism
# ...                       ...
# 16719                 Ukiyo_e
# 16723                 Ukiyo_e
# 16726                 Ukiyo_e
# 16734                 Ukiyo_e
# 16742                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 7                                              alice-baber_wheel-of-day-1971
# 11                                                    atsuko-tanaka_93e-1993
# 19                                                brice-marden_untitled-1996
# ...                                                                      ...
# 16719                 utagawa-kuniyoshi_woman-doing-her-laundry-in-the-river
# 16723                                             utagawa-kuniyoshi_women-12
# 16726                                             utagawa-kuniyoshi_women-19
# 16734             utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
#
#         emotype  \
# 0      negative
# 1      negative
# 7      positive
# 11     negative
# 19     positive
# ...         ...
# 16719  positive
# 16723  positive
# 16726  positive
# 16734  positive
# 16742  positive
#
#                                                                                                     path
# 0                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 7                               dataset\wikiart\Abstract_Expressionism\alice-baber_wheel-of-day-1971.jpg
# 11                                     dataset\wikiart\Abstract_Expressionism\atsuko-tanaka_93e-1993.jpg
# 19                                 dataset\wikiart\Abstract_Expressionism\brice-marden_untitled-1996.jpg
# ...                                                                                                  ...
# 16719                 dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_woman-doing-her-laundry-in-the-river.jpg
# 16723                                             dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-12.jpg
# 16726                                             dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-19.jpg
# 16734             dataset\wikiart\Ukiyo_e\utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship.jpg
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
#
# [3666 rows x 4 columns]

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotype'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
resnet34model = models.resnet34(pretrained = False)
print(resnet34model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
resnet34model.fc=nn.Sequential(nn.Linear(512,4096),
                                nn.ReLU(),
                               nn.Linear(4096,4096),
                                nn.ReLU(),
                               nn.Linear(4096,2),
                               nn.Softmax())

# %%
#opt_func = partial(ranger)
#model=xresnet34_deeper
#learn = vision_learner(dls, model,loss_func=CrossEntropyLossFlat(),pretrained=False, metrics=error_rate,opt_func=opt_func)

# %%
resnet34model

# %%
opt_func = partial(ranger)

learn = Learner(dls, resnet34model,loss_func=CrossEntropyLossFlat(), metrics=error_rate,opt_func=opt_func)

# %%
lr=learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\torch\nn\modules\container.py:139: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
lr=lr[2]

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='artemis1_classification_model_resnet34_2FC_refined_beforemode_balanced_binary_cross', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.656797</td>
#       <td>0.606063</td>
#       <td>0.306958</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.617271</td>
#       <td>0.587677</td>
#       <td>0.301501</td>
#       <td>01:48</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.596626</td>
#       <td>0.563238</td>
#       <td>0.260573</td>
#       <td>01:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.590382</td>
#       <td>0.578072</td>
#       <td>0.286494</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.595368</td>
#       <td>0.566188</td>
#       <td>0.272851</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.585095</td>
#       <td>0.572827</td>
#       <td>0.271487</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.573359</td>
#       <td>0.569189</td>
#       <td>0.272851</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.567031</td>
#       <td>0.565152</td>
#       <td>0.264666</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.576088</td>
#       <td>0.560871</td>
#       <td>0.268759</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.561807</td>
#       <td>0.582588</td>
#       <td>0.283765</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.548341</td>
#       <td>0.565226</td>
#       <td>0.274216</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.551146</td>
#       <td>0.568866</td>
#       <td>0.278308</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.553794</td>
#       <td>0.568209</td>
#       <td>0.264666</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.546683</td>
#       <td>0.558603</td>
#       <td>0.261937</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.542308</td>
#       <td>0.552965</td>
#       <td>0.266030</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.543805</td>
#       <td>0.560346</td>
#       <td>0.252387</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.538330</td>
#       <td>0.571891</td>
#       <td>0.279673</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.531066</td>
#       <td>0.568407</td>
#       <td>0.266030</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.532348</td>
#       <td>0.578993</td>
#       <td>0.289222</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.534153</td>
#       <td>0.564737</td>
#       <td>0.257844</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.518688</td>
#       <td>0.599434</td>
#       <td>0.302865</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.515258</td>
#       <td>0.551522</td>
#       <td>0.257844</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.501870</td>
#       <td>0.561457</td>
#       <td>0.257844</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.520619</td>
#       <td>0.557650</td>
#       <td>0.261937</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.491339</td>
#       <td>0.623166</td>
#       <td>0.335607</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.484720</td>
#       <td>0.565965</td>
#       <td>0.257844</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.478576</td>
#       <td>0.546926</td>
#       <td>0.251023</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.464476</td>
#       <td>0.558113</td>
#       <td>0.271487</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.468850</td>
#       <td>0.560753</td>
#       <td>0.259209</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.469991</td>
#       <td>0.557426</td>
#       <td>0.260573</td>
#       <td>01:49</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.6060631275177002.
# Better model found at epoch 1 with valid_loss value: 0.5876769423484802.
# Better model found at epoch 2 with valid_loss value: 0.5632379651069641.
# Better model found at epoch 8 with valid_loss value: 0.5608713626861572.
# Better model found at epoch 13 with valid_loss value: 0.5586026906967163.
# Better model found at epoch 14 with valid_loss value: 0.5529645681381226.
# Better model found at epoch 21 with valid_loss value: 0.5515217185020447.
# Better model found at epoch 26 with valid_loss value: 0.5469258427619934.

# %%
model=learn.load('artemis1_classification_model_resnet34_2FC_refined_beforemode_balanced_binary_cross')
# Out:
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py:58: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
interp=ClassificationInterpretation(model,dls.valid,model.loss_func)

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#     negative       0.72      0.87      0.78       386
#     positive       0.81      0.62      0.70       347
#
#     accuracy                           0.75       733
#    macro avg       0.76      0.74      0.74       733
# weighted avg       0.76      0.75      0.74       733

# %%
model.loss_func
