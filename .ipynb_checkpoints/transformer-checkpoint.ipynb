# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt
import os
from fastai.vision.all import *
from transformers import SwinForImageClassification
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition
# 0       something else          10
# 1              sadness          10
# 2       something else          10
# 3          contentment          10
# 4                  awe          10
# ...                ...         ...
# 454679             awe          48
# 454680             awe           8
# 454681      excitement           8
# 454682     contentment           8
# 454683            fear          10
#
# [454684 rows x 4 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*1.0 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
def emtype(x):
    if x.emotion=='sadness':
        return "negative"
    elif x.emotion=='fear':
        return "negative"
    elif x.emotion=='disgust':
        return "negative"
    elif x.emotion=='anger':
        return "negative"
    elif x.emotion=='contentment':
        return "positive"
    elif x.emotion=='awe':
        return "positive"
    elif x.emotion=='amusement':
        return "positive"
    elif x.emotion=='excitement':
        return "positive"
    else:
        return "something else"

# %%
dfemo=df
dfemo['emotype']= dfemo.apply(emtype,axis=1)
dfemo
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition         emotype
# 0       something else          10  something else
# 1              sadness          10        negative
# 2       something else          10  something else
# 3          contentment          10        positive
# 4                  awe          10        positive
# ...                ...         ...             ...
# 454679             awe          48        positive
# 454680             awe           8        positive
# 454681      excitement           8        positive
# 454682     contentment           8        positive
# 454683            fear          10        negative
#
# [454684 rows x 5 columns]

# %%
#dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()
#dfemo

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotype"].agg(modo).reset_index()

dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                                aaron-siskind_feet-102-1957
# 4                                          aaron-siskind_gloucester-16a-1944
# ...                                                                      ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
# 80029     utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 80030                                   utagawa-toyokuni_three-beauties-snow
#
#                                     emotype
# 0      [positive, negative, something else]
# 1      [negative, positive, something else]
# 2                [negative, something else]
# 3      [something else, negative, positive]
# 4                [something else, negative]
# ...                                     ...
# 80026                  [positive, negative]
# 80027                  [positive, negative]
# 80028                  [positive, negative]
# 80029            [positive, something else]
# 80030            [positive, something else]
#
# [80031 rows x 3 columns]

# %%
t=type(dfemo.emotype[0])
dfemo=dfemo[dfemo["emotype"].apply(lambda x: type(x) !=t )].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16754                 Ukiyo_e
# 16755                 Ukiyo_e
# 16756                 Ukiyo_e
# 16757                 Ukiyo_e
# 16758                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16754                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16755     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16756                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16757  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16758                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16754  positive
# 16755  positive
# 16756  positive
# 16757  positive
# 16758  positive
#
# [16759 rows x 3 columns]

# %%
dfemo=dfemo[dfemo.emotype!="something else"].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
# [16744 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype  \
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
#                                                                                                     path
# 0                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 2                                    dataset\wikiart\Abstract_Expressionism\alexander-calder_the-dog.jpg
# 3                     dataset\wikiart\Abstract_Expressionism\alice-baber_abstract-composition-1969-1.jpg
# 4                        dataset\wikiart\Abstract_Expressionism\alice-baber_lord-of-the-rainbow-1976.jpg
# ...                                                                                                  ...
# 16739                      dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata.jpg
# 16740     dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono.jpg
# 16741                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_view-of-oshima-from-atami-beach.jpg
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
# 16743                                                 dataset\wikiart\Ukiyo_e\utagawa-toyokuni_dance.jpg
#
# [16744 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
frac=1-(dfemo.emotype.value_counts()[1]/dfemo.emotype.value_counts()[0])

dfemo = dfemo.drop(dfemo[dfemo['emotype'] == "positive"].sample(frac=frac).index)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 11     Abstract_Expressionism
# 13     Abstract_Expressionism
# 22     Abstract_Expressionism
# ...                       ...
# 16714                 Ukiyo_e
# 16724                 Ukiyo_e
# 16734                 Ukiyo_e
# 16735                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                        painting  \
# 0                                                 aaron-siskind_yuchitan-1-1955
# 1                                                    aki-kuroda_conti-nuit-1979
# 11                                                       atsuko-tanaka_93e-1993
# 13                                                  atsuko-tanaka_untitled-1999
# 22                                              clyfford-still_1947-r-no-1-1947
# ...                                                                         ...
# 16714  utagawa-kuniyoshi_the-hundred-and-eight-heroes-of-the-popular-suikoden-1
# 16724                                                utagawa-kuniyoshi_women-13
# 16734                utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship
# 16735                                 utagawa-sadatora_hinaogi-of-the-daikokuya
# 16743                                                    utagawa-toyokuni_dance
#
#         emotype  \
# 0      negative
# 1      negative
# 11     negative
# 13     positive
# 22     negative
# ...         ...
# 16714  negative
# 16724  positive
# 16734  positive
# 16735  positive
# 16743  positive
#
#                                                                                                        path
# 0                                  dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                     dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 11                                        dataset\wikiart\Abstract_Expressionism\atsuko-tanaka_93e-1993.jpg
# 13                                   dataset\wikiart\Abstract_Expressionism\atsuko-tanaka_untitled-1999.jpg
# 22                               dataset\wikiart\Abstract_Expressionism\clyfford-still_1947-r-no-1-1947.jpg
# ...                                                                                                     ...
# 16714  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-hundred-and-eight-heroes-of-the-popular-suikoden-1.jpg
# 16724                                                dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_women-13.jpg
# 16734                dataset\wikiart\Ukiyo_e\utagawa-sadatora_great-harbors-for-the-lucky-treasure-ship.jpg
# 16735                                 dataset\wikiart\Ukiyo_e\utagawa-sadatora_hinaogi-of-the-daikokuya.jpg
# 16743                                                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni_dance.jpg
#
# [3666 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotype'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
model = SwinForImageClassification.from_pretrained('microsoft/swin-small-patch4-window7-224')

# %%
class DropOutput(Callback):
    def after_pred(self): self.learn.pred = self.pred[0]

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), cbs=[DropOutput], metrics=error_rate)

# %%
lr=learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lr=lr[3]

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='artemis1_classification_model_swin-small-patch4-window7-224_refined_beforemode_balanced_binary_cross', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.700767</td>
#       <td>4.794775</td>
#       <td>0.882674</td>
#       <td>18:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.268274</td>
#       <td>1.551832</td>
#       <td>0.372442</td>
#       <td>18:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.722828</td>
#       <td>0.781601</td>
#       <td>0.316508</td>
#       <td>18:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.620336</td>
#       <td>0.663386</td>
#       <td>0.283765</td>
#       <td>18:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.567998</td>
#       <td>0.594181</td>
#       <td>0.270123</td>
#       <td>18:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.533011</td>
#       <td>0.535182</td>
#       <td>0.249659</td>
#       <td>18:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.494568</td>
#       <td>0.521121</td>
#       <td>0.241473</td>
#       <td>18:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.507008</td>
#       <td>0.482938</td>
#       <td>0.231924</td>
#       <td>18:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.473671</td>
#       <td>0.470487</td>
#       <td>0.225102</td>
#       <td>18:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.455939</td>
#       <td>0.458052</td>
#       <td>0.221010</td>
#       <td>18:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.444830</td>
#       <td>0.459702</td>
#       <td>0.210095</td>
#       <td>17:35</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.439130</td>
#       <td>0.441804</td>
#       <td>0.212824</td>
#       <td>17:29</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.434242</td>
#       <td>0.424082</td>
#       <td>0.207367</td>
#       <td>17:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.404741</td>
#       <td>0.421671</td>
#       <td>0.206003</td>
#       <td>17:29</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.417524</td>
#       <td>0.412264</td>
#       <td>0.204638</td>
#       <td>17:30</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.397612</td>
#       <td>0.405826</td>
#       <td>0.197817</td>
#       <td>17:28</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.387228</td>
#       <td>0.405537</td>
#       <td>0.196453</td>
#       <td>18:33</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.379067</td>
#       <td>0.403726</td>
#       <td>0.195089</td>
#       <td>18:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.359478</td>
#       <td>0.405197</td>
#       <td>0.190996</td>
#       <td>17:54</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.379097</td>
#       <td>0.395212</td>
#       <td>0.188267</td>
#       <td>17:54</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.367402</td>
#       <td>0.394035</td>
#       <td>0.185539</td>
#       <td>17:49</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.345279</td>
#       <td>0.398007</td>
#       <td>0.185539</td>
#       <td>16:55</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.356579</td>
#       <td>0.389213</td>
#       <td>0.185539</td>
#       <td>16:54</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.351967</td>
#       <td>0.393719</td>
#       <td>0.182810</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.338340</td>
#       <td>0.385907</td>
#       <td>0.180082</td>
#       <td>16:53</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.338656</td>
#       <td>0.380325</td>
#       <td>0.182810</td>
#       <td>18:08</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.317016</td>
#       <td>0.382484</td>
#       <td>0.177353</td>
#       <td>18:08</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.320149</td>
#       <td>0.384425</td>
#       <td>0.175989</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.320454</td>
#       <td>0.385125</td>
#       <td>0.175989</td>
#       <td>20:40</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.296673</td>
#       <td>0.385186</td>
#       <td>0.175989</td>
#       <td>16:53</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 4.794775485992432.
# Better model found at epoch 1 with valid_loss value: 1.5518320798873901.
# Better model found at epoch 2 with valid_loss value: 0.7816005349159241.
# Better model found at epoch 3 with valid_loss value: 0.6633855700492859.
# Better model found at epoch 4 with valid_loss value: 0.5941811800003052.
# Better model found at epoch 5 with valid_loss value: 0.5351817011833191.
# Better model found at epoch 6 with valid_loss value: 0.5211207866668701.
# Better model found at epoch 7 with valid_loss value: 0.48293763399124146.
# Better model found at epoch 8 with valid_loss value: 0.47048741579055786.
# Better model found at epoch 9 with valid_loss value: 0.45805224776268005.
# Better model found at epoch 11 with valid_loss value: 0.4418042302131653.
# Better model found at epoch 12 with valid_loss value: 0.4240824580192566.
# Better model found at epoch 13 with valid_loss value: 0.4216706156730652.
# Better model found at epoch 14 with valid_loss value: 0.4122640788555145.
# Better model found at epoch 15 with valid_loss value: 0.4058263897895813.
# Better model found at epoch 16 with valid_loss value: 0.4055373966693878.
# Better model found at epoch 17 with valid_loss value: 0.40372633934020996.
# Better model found at epoch 19 with valid_loss value: 0.3952122628688812.
# Better model found at epoch 20 with valid_loss value: 0.39403513073921204.
# Better model found at epoch 22 with valid_loss value: 0.38921308517456055.
# Better model found at epoch 24 with valid_loss value: 0.38590696454048157.
# Better model found at epoch 25 with valid_loss value: 0.3803253471851349.

# %%
model=learn.load('artemis1_classification_model_swin-small-patch4-window7-224_refined_beforemode_balanced_binary_cross')
# Out:
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py:58: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
interp=ClassificationInterpretation(model,dls.valid,model.loss_func)

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.82       364
#     positive       0.84      0.78      0.81       369
#
#     accuracy                           0.82       733
#    macro avg       0.82      0.82      0.82       733
# weighted avg       0.82      0.82      0.82       733
