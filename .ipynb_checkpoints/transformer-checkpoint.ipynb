# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt
import torchvision.transforms
import os
from fastai.vision.all import *
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
from transformers import ViTForImageClassification

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style                                           painting  \
# 0       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                    ...                                                ...
# 454679              Cubism                           gino-severini_a-dancer-1
# 454680         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454681         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454682         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454683              Cubism                      joan-miro_not_detected_227963
#
#                emotion  repetition
# 0       something else          10
# 1              sadness          10
# 2       something else          10
# 3          contentment          10
# 4                  awe          10
# ...                ...         ...
# 454679             awe          48
# 454680             awe           8
# 454681      excitement           8
# 454682     contentment           8
# 454683            fear          10
#
# [454684 rows x 4 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*1.0 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
def emtype(x):
    if x.emotion=='sadness':
        return "negative"
    elif x.emotion=='fear':
        return "negative"
    elif x.emotion=='disgust':
        return "negative"
    elif x.emotion=='anger':
        return "negative"
    elif x.emotion=='contentment':
        return "positive"
    elif x.emotion=='awe':
        return "positive"
    elif x.emotion=='amusement':
        return "positive"
    elif x.emotion=='excitement':
        return "positive"
    else:
        return "something else"

# %%
dfemo=df
dfemo['emotype']= dfemo.apply(emtype,axis=1)
dfemo
# Out:
#                  art_style                                           painting  \
# 0       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 1       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 2       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 3       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# 4       Post_Impressionism  vincent-van-gogh_portrait-of-madame-ginoux-l-a...
# ...                    ...                                                ...
# 454679              Cubism                           gino-severini_a-dancer-1
# 454680         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454681         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454682         Romanticism                  ivan-aivazovsky_sea-at-night-1861
# 454683              Cubism                      joan-miro_not_detected_227963
#
#                emotion  repetition         emotype
# 0       something else          10  something else
# 1              sadness          10        negative
# 2       something else          10  something else
# 3          contentment          10        positive
# 4                  awe          10        positive
# ...                ...         ...             ...
# 454679             awe          48        positive
# 454680             awe           8        positive
# 454681      excitement           8        positive
# 454682     contentment           8        positive
# 454683            fear          10        negative
#
# [454684 rows x 5 columns]

# %%
#dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()
#dfemo

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotype"].agg(modo).reset_index()

dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                 painting  \
# 0                           aaron-siskind_acolman-1-1955
# 1                             aaron-siskind_chicago-1951
# 2                           aaron-siskind_chicago-6-1961
# 3                            aaron-siskind_feet-102-1957
# 4                      aaron-siskind_gloucester-16a-1944
# ...                                                  ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-...
# 80027                utagawa-toyokuni_the-heian-courtier
# 80028                     utagawa-toyokuni_the-promenade
# 80029  utagawa-toyokuni_three-beauties-playing-battle...
# 80030               utagawa-toyokuni_three-beauties-snow
#
#                                     emotype
# 0      [positive, negative, something else]
# 1      [negative, positive, something else]
# 2                [negative, something else]
# 3      [something else, negative, positive]
# 4                [something else, negative]
# ...                                     ...
# 80026                  [positive, negative]
# 80027                  [positive, negative]
# 80028                  [positive, negative]
# 80029            [positive, something else]
# 80030            [positive, something else]
#
# [80031 rows x 3 columns]

# %%
t=type(dfemo.emotype[0])
dfemo=dfemo[dfemo["emotype"].apply(lambda x: type(x) !=t )].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16754                 Ukiyo_e
# 16755                 Ukiyo_e
# 16756                 Ukiyo_e
# 16757                 Ukiyo_e
# 16758                 Ukiyo_e
#
#                                                 painting   emotype
# 0                          aaron-siskind_yuchitan-1-1955  negative
# 1                             aki-kuroda_conti-nuit-1979  negative
# 2                               alexander-calder_the-dog  positive
# 3                alice-baber_abstract-composition-1969-1  positive
# 4                   alice-baber_lord-of-the-rainbow-1976  positive
# ...                                                  ...       ...
# 16754  utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata  positive
# 16755  utagawa-toyokuni-ii_sumo-wrester-in-blue-brown...  positive
# 16756  utagawa-toyokuni-ii_view-of-oshima-from-atami-...  positive
# 16757  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-...  positive
# 16758                             utagawa-toyokuni_dance  positive
#
# [16759 rows x 3 columns]

# %%
dfemo=dfemo[dfemo.emotype!="something else"].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                 painting   emotype
# 0                          aaron-siskind_yuchitan-1-1955  negative
# 1                             aki-kuroda_conti-nuit-1979  negative
# 2                               alexander-calder_the-dog  positive
# 3                alice-baber_abstract-composition-1969-1  positive
# 4                   alice-baber_lord-of-the-rainbow-1976  positive
# ...                                                  ...       ...
# 16739  utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata  positive
# 16740  utagawa-toyokuni-ii_sumo-wrester-in-blue-brown...  positive
# 16741  utagawa-toyokuni-ii_view-of-oshima-from-atami-...  positive
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-...  positive
# 16743                             utagawa-toyokuni_dance  positive
#
# [16744 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                 painting   emotype  \
# 0                          aaron-siskind_yuchitan-1-1955  negative
# 1                             aki-kuroda_conti-nuit-1979  negative
# 2                               alexander-calder_the-dog  positive
# 3                alice-baber_abstract-composition-1969-1  positive
# 4                   alice-baber_lord-of-the-rainbow-1976  positive
# ...                                                  ...       ...
# 16739  utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata  positive
# 16740  utagawa-toyokuni-ii_sumo-wrester-in-blue-brown...  positive
# 16741  utagawa-toyokuni-ii_view-of-oshima-from-atami-...  positive
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-...  positive
# 16743                             utagawa-toyokuni_dance  positive
#
#                                                     path
# 0      dataset\wikiart\Abstract_Expressionism\aaron-s...
# 1      dataset\wikiart\Abstract_Expressionism\aki-kur...
# 2      dataset\wikiart\Abstract_Expressionism\alexand...
# 3      dataset\wikiart\Abstract_Expressionism\alice-b...
# 4      dataset\wikiart\Abstract_Expressionism\alice-b...
# ...                                                  ...
# 16739  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_se...
# 16740  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_su...
# 16741  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_vi...
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wi...
# 16743  dataset\wikiart\Ukiyo_e\utagawa-toyokuni_dance...
#
# [16744 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
frac=1-(dfemo.emotype.value_counts()[1]/dfemo.emotype.value_counts()[0])

dfemo = dfemo.drop(dfemo[dfemo['emotype'] == "positive"].sample(frac=frac).index)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 4      Abstract_Expressionism
# 11     Abstract_Expressionism
# ...                       ...
# 16714                 Ukiyo_e
# 16717                 Ukiyo_e
# 16719                 Ukiyo_e
# 16724                 Ukiyo_e
# 16728                 Ukiyo_e
#
#                                                 painting   emotype  \
# 0                          aaron-siskind_yuchitan-1-1955  negative
# 1                             aki-kuroda_conti-nuit-1979  negative
# 2                               alexander-calder_the-dog  positive
# 4                   alice-baber_lord-of-the-rainbow-1976  positive
# 11                                atsuko-tanaka_93e-1993  negative
# ...                                                  ...       ...
# 16714  utagawa-kuniyoshi_the-hundred-and-eight-heroes...  negative
# 16717   utagawa-kuniyoshi_the-seven-gods-of-good-fortune  positive
# 16719  utagawa-kuniyoshi_woman-doing-her-laundry-in-t...  positive
# 16724                         utagawa-kuniyoshi_women-13  positive
# 16728                         utagawa-kuniyoshi_women-27  positive
#
#                                                     path
# 0      dataset\wikiart\Abstract_Expressionism\aaron-s...
# 1      dataset\wikiart\Abstract_Expressionism\aki-kur...
# 2      dataset\wikiart\Abstract_Expressionism\alexand...
# 4      dataset\wikiart\Abstract_Expressionism\alice-b...
# 11     dataset\wikiart\Abstract_Expressionism\atsuko-...
# ...                                                  ...
# 16714  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-...
# 16717  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-...
# 16719  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_woma...
# 16724  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_wome...
# 16728  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_wome...
#
# [3666 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotype'),
                  item_tfms=Resize(224,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Aren\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading pytorch_model.bin:   0%|          | 0.00/346M [00:00<?, ?B/s]

# %%
class DropOutput(Callback):
    def after_pred(self): self.learn.pred = self.pred[0]

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), cbs=[DropOutput], metrics=error_rate)

# %%
learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# (#2) [9.712935447692871,0.9986357688903809]

# %%
lr=learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lr=lr[2]

# %%
learn.fit_flat_cos(30,lr,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='artemis1_classification_model_vit_base_patch16_224_refined_beforemode_balanced_binary_cross', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.725957</td>
#       <td>0.798622</td>
#       <td>0.506139</td>
#       <td>18:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.636019</td>
#       <td>0.556240</td>
#       <td>0.268759</td>
#       <td>17:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.580104</td>
#       <td>0.673311</td>
#       <td>0.375171</td>
#       <td>17:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.542134</td>
#       <td>0.534467</td>
#       <td>0.256480</td>
#       <td>17:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.542845</td>
#       <td>0.652818</td>
#       <td>0.327422</td>
#       <td>17:43</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.525784</td>
#       <td>0.528492</td>
#       <td>0.255116</td>
#       <td>17:43</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.541278</td>
#       <td>0.572162</td>
#       <td>0.278308</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.546157</td>
#       <td>0.509724</td>
#       <td>0.266030</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.523913</td>
#       <td>0.505197</td>
#       <td>0.260573</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.524412</td>
#       <td>0.554991</td>
#       <td>0.282401</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.516091</td>
#       <td>0.537092</td>
#       <td>0.268759</td>
#       <td>17:39</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.514172</td>
#       <td>0.527795</td>
#       <td>0.270123</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.522700</td>
#       <td>0.518039</td>
#       <td>0.255116</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.519504</td>
#       <td>0.522434</td>
#       <td>0.275580</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.495151</td>
#       <td>0.510928</td>
#       <td>0.252387</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.496984</td>
#       <td>0.499433</td>
#       <td>0.255116</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.514039</td>
#       <td>0.493135</td>
#       <td>0.244202</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.477231</td>
#       <td>0.503511</td>
#       <td>0.260573</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.510948</td>
#       <td>0.502931</td>
#       <td>0.266030</td>
#       <td>17:47</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.507909</td>
#       <td>0.511820</td>
#       <td>0.242838</td>
#       <td>17:46</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.474814</td>
#       <td>0.534546</td>
#       <td>0.283765</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.483743</td>
#       <td>0.499364</td>
#       <td>0.255116</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.474209</td>
#       <td>0.548318</td>
#       <td>0.267394</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.483175</td>
#       <td>0.506183</td>
#       <td>0.255116</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.471766</td>
#       <td>0.512058</td>
#       <td>0.268759</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.468168</td>
#       <td>0.513731</td>
#       <td>0.248295</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.425416</td>
#       <td>0.525095</td>
#       <td>0.249659</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.440989</td>
#       <td>0.504351</td>
#       <td>0.248295</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.400415</td>
#       <td>0.523052</td>
#       <td>0.244202</td>
#       <td>17:40</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.385593</td>
#       <td>0.524126</td>
#       <td>0.237381</td>
#       <td>17:41</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7986219525337219.
# Better model found at epoch 1 with valid_loss value: 0.5562399625778198.
# Better model found at epoch 3 with valid_loss value: 0.5344674587249756.
# Better model found at epoch 5 with valid_loss value: 0.5284923315048218.
# Better model found at epoch 7 with valid_loss value: 0.509723961353302.
# Better model found at epoch 8 with valid_loss value: 0.505197286605835.
# Better model found at epoch 15 with valid_loss value: 0.4994329810142517.
# Better model found at epoch 16 with valid_loss value: 0.49313458800315857.

# %%
model=learn.load('artemis1_classification_model_vit_base_patch16_224_refined_beforemode_balanced_binary_cross')

# %%
interp=ClassificationInterpretation(model,dls.valid,model.loss_func)

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#     negative       0.72      0.83      0.77       362
#     positive       0.81      0.68      0.74       371
#
#     accuracy                           0.76       733
#    macro avg       0.76      0.76      0.75       733
# weighted avg       0.76      0.76      0.75       733
