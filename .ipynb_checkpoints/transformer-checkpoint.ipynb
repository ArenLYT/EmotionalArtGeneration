# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt
import os
from fastai.vision.all import *
from transformers import AutoModelForImageClassification
#os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
df=pd.read_csv('ArtEmisv1.csv')
df
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition
# 0       something else          10
# 1              sadness          10
# 2       something else          10
# 3          contentment          10
# 4                  awe          10
# ...                ...         ...
# 454679             awe          48
# 454680             awe           8
# 454681      excitement           8
# 454682     contentment           8
# 454683            fear          10
#
# [454684 rows x 4 columns]

# %%
def modo(x):
    if  x.value_counts()[0]>=sum(x.value_counts())*1.0 :
        return pd.Series.mode(x)
    else:
        return x.value_counts()[:3].index.tolist()

# %%
def emtype(x):
    if x.emotion=='sadness':
        return "negative"
    elif x.emotion=='fear':
        return "negative"
    elif x.emotion=='disgust':
        return "negative"
    elif x.emotion=='anger':
        return "negative"
    elif x.emotion=='contentment':
        return "positive"
    elif x.emotion=='awe':
        return "positive"
    elif x.emotion=='amusement':
        return "positive"
    elif x.emotion=='excitement':
        return "positive"
    else:
        return "something else"

# %%
dfemo=df
dfemo['emotype']= dfemo.apply(emtype,axis=1)
dfemo
# Out:
#                  art_style  \
# 0       Post_Impressionism
# 1       Post_Impressionism
# 2       Post_Impressionism
# 3       Post_Impressionism
# 4       Post_Impressionism
# ...                    ...
# 454679              Cubism
# 454680         Romanticism
# 454681         Romanticism
# 454682         Romanticism
# 454683              Cubism
#
#                                                             painting  \
# 0       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 1       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 2       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 3       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# 4       vincent-van-gogh_portrait-of-madame-ginoux-l-arlesienne-1890
# ...                                                              ...
# 454679                                      gino-severini_a-dancer-1
# 454680                             ivan-aivazovsky_sea-at-night-1861
# 454681                             ivan-aivazovsky_sea-at-night-1861
# 454682                             ivan-aivazovsky_sea-at-night-1861
# 454683                                 joan-miro_not_detected_227963
#
#                emotion  repetition         emotype
# 0       something else          10  something else
# 1              sadness          10        negative
# 2       something else          10  something else
# 3          contentment          10        positive
# 4                  awe          10        positive
# ...                ...         ...             ...
# 454679             awe          48        positive
# 454680             awe           8        positive
# 454681      excitement           8        positive
# 454682     contentment           8        positive
# 454683            fear          10        negative
#
# [454684 rows x 5 columns]

# %%
#dfemo=dfemo.groupby(["art_style","painting"])["emotion"].agg(modo).reset_index()
#dfemo

# %%
dfemo=dfemo.groupby(["art_style","painting"])["emotype"].agg(modo).reset_index()

dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 80026                 Ukiyo_e
# 80027                 Ukiyo_e
# 80028                 Ukiyo_e
# 80029                 Ukiyo_e
# 80030                 Ukiyo_e
#
#                                                                     painting  \
# 0                                               aaron-siskind_acolman-1-1955
# 1                                                 aaron-siskind_chicago-1951
# 2                                               aaron-siskind_chicago-6-1961
# 3                                                aaron-siskind_feet-102-1957
# 4                                          aaron-siskind_gloucester-16a-1944
# ...                                                                      ...
# 80026  utagawa-toyokuni_the-actor-otani-monzo-in-the-role-of-igarashi-tenzen
# 80027                                    utagawa-toyokuni_the-heian-courtier
# 80028                                         utagawa-toyokuni_the-promenade
# 80029     utagawa-toyokuni_three-beauties-playing-battledore-and-shuttlecock
# 80030                                   utagawa-toyokuni_three-beauties-snow
#
#                                     emotype
# 0      [positive, negative, something else]
# 1      [negative, positive, something else]
# 2                [negative, something else]
# 3      [something else, negative, positive]
# 4                [something else, negative]
# ...                                     ...
# 80026                  [positive, negative]
# 80027                  [positive, negative]
# 80028                  [positive, negative]
# 80029            [positive, something else]
# 80030            [positive, something else]
#
# [80031 rows x 3 columns]

# %%
t=type(dfemo.emotype[0])
dfemo=dfemo[dfemo["emotype"].apply(lambda x: type(x) !=t )].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16754                 Ukiyo_e
# 16755                 Ukiyo_e
# 16756                 Ukiyo_e
# 16757                 Ukiyo_e
# 16758                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16754                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16755     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16756                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16757  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16758                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16754  positive
# 16755  positive
# 16756  positive
# 16757  positive
# 16758  positive
#
# [16759 rows x 3 columns]

# %%
dfemo=dfemo[dfemo.emotype!="something else"].reset_index()
dfemo = dfemo.drop('index', axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
# [16744 rows x 3 columns]

# %%
dfemo['path']= dfemo.apply(lambda x: 'dataset\\wikiart\\'+x['art_style']+"\\"+ x['painting']+".jpg", axis=1)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 2      Abstract_Expressionism
# 3      Abstract_Expressionism
# 4      Abstract_Expressionism
# ...                       ...
# 16739                 Ukiyo_e
# 16740                 Ukiyo_e
# 16741                 Ukiyo_e
# 16742                 Ukiyo_e
# 16743                 Ukiyo_e
#
#                                                                     painting  \
# 0                                              aaron-siskind_yuchitan-1-1955
# 1                                                 aki-kuroda_conti-nuit-1979
# 2                                                   alexander-calder_the-dog
# 3                                    alice-baber_abstract-composition-1969-1
# 4                                       alice-baber_lord-of-the-rainbow-1976
# ...                                                                      ...
# 16739                      utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata
# 16740     utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono
# 16741                    utagawa-toyokuni-ii_view-of-oshima-from-atami-beach
# 16742  utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara
# 16743                                                 utagawa-toyokuni_dance
#
#         emotype  \
# 0      negative
# 1      negative
# 2      positive
# 3      positive
# 4      positive
# ...         ...
# 16739  positive
# 16740  positive
# 16741  positive
# 16742  positive
# 16743  positive
#
#                                                                                                     path
# 0                               dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                  dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 2                                    dataset\wikiart\Abstract_Expressionism\alexander-calder_the-dog.jpg
# 3                     dataset\wikiart\Abstract_Expressionism\alice-baber_abstract-composition-1969-1.jpg
# 4                        dataset\wikiart\Abstract_Expressionism\alice-baber_lord-of-the-rainbow-1976.jpg
# ...                                                                                                  ...
# 16739                      dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_segawa-kikunojo-v-as-onnagata.jpg
# 16740     dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_sumo-wrester-in-blue-brown-striped-underkimono.jpg
# 16741                    dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_view-of-oshima-from-atami-beach.jpg
# 16742  dataset\wikiart\Ukiyo_e\utagawa-toyokuni-ii_wild-geese-at-miho-kiyomi-temple-suruga-yoshiwara.jpg
# 16743                                                 dataset\wikiart\Ukiyo_e\utagawa-toyokuni_dance.jpg
#
# [16744 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
frac=1-(dfemo.emotype.value_counts()[1]/dfemo.emotype.value_counts()[0])

dfemo = dfemo.drop(dfemo[dfemo['emotype'] == "positive"].sample(frac=frac).index)
dfemo
# Out:
#                     art_style  \
# 0      Abstract_Expressionism
# 1      Abstract_Expressionism
# 4      Abstract_Expressionism
# 11     Abstract_Expressionism
# 17     Abstract_Expressionism
# ...                       ...
# 16707                 Ukiyo_e
# 16710                 Ukiyo_e
# 16713                 Ukiyo_e
# 16714                 Ukiyo_e
# 16716                 Ukiyo_e
#
#                                                                        painting  \
# 0                                                 aaron-siskind_yuchitan-1-1955
# 1                                                    aki-kuroda_conti-nuit-1979
# 4                                          alice-baber_lord-of-the-rainbow-1976
# 11                                                       atsuko-tanaka_93e-1993
# 17                                          blinky-palermo_fensterkreuz-ii-1966
# ...                                                                         ...
# 16707          utagawa-kuniyoshi_tametomo-rescued-from-the-sea-monster-by-tengu
# 16710                                            utagawa-kuniyoshi_the-actor-15
# 16713                                utagawa-kuniyoshi_the-ghost-in-the-lantern
# 16714  utagawa-kuniyoshi_the-hundred-and-eight-heroes-of-the-popular-suikoden-1
# 16716                                        utagawa-kuniyoshi_the-poetess-ukon
#
#         emotype  \
# 0      negative
# 1      negative
# 4      positive
# 11     negative
# 17     positive
# ...         ...
# 16707  negative
# 16710  negative
# 16713  negative
# 16714  negative
# 16716  positive
#
#                                                                                                        path
# 0                                  dataset\wikiart\Abstract_Expressionism\aaron-siskind_yuchitan-1-1955.jpg
# 1                                     dataset\wikiart\Abstract_Expressionism\aki-kuroda_conti-nuit-1979.jpg
# 4                           dataset\wikiart\Abstract_Expressionism\alice-baber_lord-of-the-rainbow-1976.jpg
# 11                                        dataset\wikiart\Abstract_Expressionism\atsuko-tanaka_93e-1993.jpg
# 17                           dataset\wikiart\Abstract_Expressionism\blinky-palermo_fensterkreuz-ii-1966.jpg
# ...                                                                                                     ...
# 16707          dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_tametomo-rescued-from-the-sea-monster-by-tengu.jpg
# 16710                                            dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-actor-15.jpg
# 16713                                dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-ghost-in-the-lantern.jpg
# 16714  dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-hundred-and-eight-heroes-of-the-popular-suikoden-1.jpg
# 16716                                        dataset\wikiart\Ukiyo_e\utagawa-kuniyoshi_the-poetess-ukon.jpg
#
# [3666 rows x 4 columns]

# %%
plt.figure(figsize=(10,10))
plt.hist(dfemo.emotype,bins=range(0,3), rwidth=0.8,align="left")
plt.title('Histogram of Classes')
# Out:
# Text(0.5, 1.0, 'Histogram of Classes')

# %%
imageDB=DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x=ColReader('path'),
                  get_y=ColReader('emotype'),
                  item_tfms=Resize(256,ResizeMethod.Pad, PadMode.Zeros))

# %%
dls = imageDB.dataloaders(dfemo,bs=16)
dls.show_batch()
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
model = AutoModelForImageClassification.from_pretrained('microsoft/swinv2-tiny-patch4-window8-256')

# %%
class DropOutput(Callback):
    def after_pred(self): self.learn.pred = self.pred[0]

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), cbs=[DropOutput], metrics=error_rate)

# %%
lr=learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
learn.recorder.plot_lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lrp=lr[3]

# %%
learn.fit_flat_cos(30,lrp,pct_start=0.75, cbs=[SaveModelCallback (monitor='valid_loss', 
                                                                  comp=None, 
                                                                  min_delta=0.0,
                                                                  fname='artemis1_classification_model_swinv2-tiny-patch4-window8-256_refined_beforemode_balanced_binary_cross', 
                                                                  every_epoch=False,
                                                                  at_end=False,
                                                                  with_opt=False, 
                                                                  reset_on_fit=True)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.880239</td>
#       <td>3.182474</td>
#       <td>0.698499</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.276171</td>
#       <td>0.962490</td>
#       <td>0.387449</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.847797</td>
#       <td>0.731542</td>
#       <td>0.336971</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.737488</td>
#       <td>0.664139</td>
#       <td>0.301501</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.673921</td>
#       <td>0.579736</td>
#       <td>0.275580</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.595074</td>
#       <td>0.546597</td>
#       <td>0.257844</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.592640</td>
#       <td>0.518805</td>
#       <td>0.241473</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.560970</td>
#       <td>0.496775</td>
#       <td>0.221010</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.525367</td>
#       <td>0.483525</td>
#       <td>0.210095</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.521492</td>
#       <td>0.468232</td>
#       <td>0.207367</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.496528</td>
#       <td>0.460708</td>
#       <td>0.200546</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.488802</td>
#       <td>0.450289</td>
#       <td>0.221010</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.482971</td>
#       <td>0.443556</td>
#       <td>0.203274</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.458418</td>
#       <td>0.436824</td>
#       <td>0.210095</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.454643</td>
#       <td>0.429653</td>
#       <td>0.204638</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.481180</td>
#       <td>0.424182</td>
#       <td>0.200546</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.444864</td>
#       <td>0.422772</td>
#       <td>0.196453</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.438129</td>
#       <td>0.413689</td>
#       <td>0.189632</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.444931</td>
#       <td>0.409626</td>
#       <td>0.189632</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.418949</td>
#       <td>0.407679</td>
#       <td>0.185539</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.419239</td>
#       <td>0.404978</td>
#       <td>0.185539</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.419065</td>
#       <td>0.400278</td>
#       <td>0.174625</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.400061</td>
#       <td>0.396686</td>
#       <td>0.175989</td>
#       <td>17:55</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.388024</td>
#       <td>0.394300</td>
#       <td>0.173261</td>
#       <td>17:56</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.398960</td>
#       <td>0.392481</td>
#       <td>0.171896</td>
#       <td>18:03</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.388316</td>
#       <td>0.392410</td>
#       <td>0.174625</td>
#       <td>17:51</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.375373</td>
#       <td>0.391587</td>
#       <td>0.171896</td>
#       <td>14:28</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.397698</td>
#       <td>0.389348</td>
#       <td>0.171896</td>
#       <td>12:54</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.387845</td>
#       <td>0.389330</td>
#       <td>0.169168</td>
#       <td>12:57</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.400665</td>
#       <td>0.389073</td>
#       <td>0.171896</td>
#       <td>12:55</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 3.182474374771118.
# Better model found at epoch 1 with valid_loss value: 0.9624896049499512.
# Better model found at epoch 2 with valid_loss value: 0.7315420508384705.
# Better model found at epoch 3 with valid_loss value: 0.6641387343406677.
# Better model found at epoch 4 with valid_loss value: 0.5797358751296997.
# Better model found at epoch 5 with valid_loss value: 0.5465965270996094.
# Better model found at epoch 6 with valid_loss value: 0.5188053250312805.
# Better model found at epoch 7 with valid_loss value: 0.49677538871765137.
# Better model found at epoch 8 with valid_loss value: 0.4835253655910492.
# Better model found at epoch 9 with valid_loss value: 0.46823182702064514.
# Better model found at epoch 10 with valid_loss value: 0.46070826053619385.
# Better model found at epoch 11 with valid_loss value: 0.45028865337371826.
# Better model found at epoch 12 with valid_loss value: 0.4435563385486603.
# Better model found at epoch 13 with valid_loss value: 0.4368239641189575.
# Better model found at epoch 14 with valid_loss value: 0.42965269088745117.
# Better model found at epoch 15 with valid_loss value: 0.42418172955513.
# Better model found at epoch 16 with valid_loss value: 0.42277154326438904.
# Better model found at epoch 17 with valid_loss value: 0.41368892788887024.
# Better model found at epoch 18 with valid_loss value: 0.40962642431259155.
# Better model found at epoch 19 with valid_loss value: 0.40767917037010193.
# Better model found at epoch 20 with valid_loss value: 0.4049782454967499.
# Better model found at epoch 21 with valid_loss value: 0.400277704000473.
# Better model found at epoch 22 with valid_loss value: 0.3966863751411438.
# Better model found at epoch 23 with valid_loss value: 0.39429983496665955.
# Better model found at epoch 24 with valid_loss value: 0.39248135685920715.
# Better model found at epoch 25 with valid_loss value: 0.3924098014831543.
# Better model found at epoch 26 with valid_loss value: 0.39158716797828674.
# Better model found at epoch 27 with valid_loss value: 0.38934847712516785.
# Better model found at epoch 28 with valid_loss value: 0.3893295228481293.
# Better model found at epoch 29 with valid_loss value: 0.3890734016895294.

# %%
model=learn.load('artemis1_classification_model_swinv2-tiny-patch4-window8-256_refined_beforemode_balanced_binary_cross')
# Out:
# C:\Users\Aren\anaconda3\envs\cupy\lib\site-packages\fastai\learner.py:58: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")

# %%
interp=ClassificationInterpretation(model,dls.valid,model.loss_func)

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#     negative       0.84      0.82      0.83       371
#     positive       0.82      0.84      0.83       362
#
#     accuracy                           0.83       733
#    macro avg       0.83      0.83      0.83       733
# weighted avg       0.83      0.83      0.83       733
